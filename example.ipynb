# %%
# %pip install numpy
# %pip install .
# Out:
# Requirement already satisfied: numpy in /home/chriamue/workspace/lenna-project/jupyter/.venv/lib/python3.8/site-packages (1.21.0)
# Note: you may need to restart the kernel to use updated packages.
# Processing /home/chriamue/workspace/lenna-project/mobilenet-plugin
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: lenna-mobilenet-plugin
#   Building wheel for lenna-mobilenet-plugin (PEP 517) ... done
#   Created wheel for lenna-mobilenet-plugin: filename=lenna_mobilenet_plugin-0.1.0-cp38-cp38-linux_x86_64.whl size=18333926 sha256=fb437f948be7cefde721881525352892a60bf9f2b90014cd8031c208a21ec8cc
#   Stored in directory: /home/chriamue/.cache/pip/wheels/00/b1/18/2871964a173314cc99241b339ad031edcfb13837928f777a42
# Successfully built lenna-mobilenet-plugin
# Installing collected packages: lenna-mobilenet-plugin
#   Attempting uninstall: lenna-mobilenet-plugin
#     Found existing installation: lenna-mobilenet-plugin 0.1.0
#     Uninstalling lenna-mobilenet-plugin-0.1.0:
#       Successfully uninstalled lenna-mobilenet-plugin-0.1.0
# Successfully installed lenna-mobilenet-plugin-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
from numpy import asarray
import lenna_mobilenet_plugin

# %%
image = Image.open("assets/lenna.png")
img = asarray(image)
print(img.shape)
# Out:
# (512, 512, 3)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F657F1E3550>

# %%
config = lenna_mobilenet_plugin.default_config()
print(config)
config["size"] = 30
config["y"] = 10
print(config)
# Out:
# {'size': 12.5, 'x': 0, 'y': 0}
# {'size': 30, 'x': 0, 'y': 10}

# %%
processed = lenna_mobilenet_plugin.process(config, img)
print(processed.shape)
processed_img = Image.fromarray(processed, 'RGB')
processed_img
# Out:
# cowboy hat
# (512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F657F1E32B0>
